# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://docs.unsloth.ai/get-started/installing-+-updating).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# Introducing Unsloth [Standby for RL](https://docs.unsloth.ai/basics/memory-efficient-rl): GRPO is now faster, uses 30% less memory with 2x longer context.
#
# Gpt-oss fine-tuning now supports 8× longer context with 0 accuracy loss. [Read more](https://docs.unsloth.ai/basics/long-context-gpt-oss-training)
#
# Unsloth now supports Text-to-Speech (TTS) models. Read our [guide here](https://docs.unsloth.ai/basics/text-to-speech-tts-fine-tuning).
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
import os
os.environ["UNSLOTH_VLLM_STANDBY"] = "1" # [NEW] Extra 30% context lengths!
if "COLAB_" not in "".join(os.environ.keys()):
    # If you're not in Colab, just use pip install or uv pip install
    # !pip install unsloth vllm
else:
    pass # For Colab / Kaggle, we need extra instructions hidden below \/

# %%
#@title Colab Extra Install { display-mode: "form" }
# %%capture
import os
# !pip install --upgrade -qqq uv
if "COLAB_" not in "".join(os.environ.keys()):
    # If you're not in Colab, just use pip install!
    # !pip install unsloth vllm
else:
    try: import numpy; get_numpy = f"numpy=={numpy.__version__}"
    except: get_numpy = "numpy"
    try: import subprocess; is_t4 = "Tesla T4" in str(subprocess.check_output(["nvidia-smi"]))
    except: is_t4 = False
    get_vllm, get_triton = ("vllm==0.9.2", "triton==3.2.0") if is_t4 else ("vllm<=0.10.2", "triton")
    # !uv pip install -qqq --upgrade \
        unsloth {get_vllm} {get_numpy} torchvision bitsandbytes xformers
    # !uv pip install -qqq {get_triton}
# !uv pip install transformers==4.55.4
# !uv pip install --no-deps trl==0.22.2

# %% [markdown]
# ### Unsloth

# %% [markdown]
# We're also introducing how you can do `GSPO` inside of Unsloth as well!
#
# The goal of this notebook is to make a vision language model solve maths problems via reinforcement learning given an image input like below:
#
# <img src="https://raw.githubusercontent.com/lupantech/MathVista/main/assets/our_new_3_datasets.png" alt="Alt text" height="256">

# %%
from unsloth import FastVisionModel
import torch
max_seq_length = 16384 # Must be this long for VLMs
lora_rank = 16 # Larger rank = smarter, but slower

model, tokenizer = FastVisionModel.from_pretrained(
    model_name = "unsloth/Qwen2.5-VL-7B-Instruct",
    max_seq_length = max_seq_length,
    load_in_4bit = True, # False for LoRA 16bit
    fast_inference = True, # Enable vLLM fast inference
    gpu_memory_utilization = 0.8, # Reduce if out of memory
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# INFO 09-16 17:55:32 [__init__.py:244] Automatically detected platform cuda.
# ERROR 09-16 17:55:39 [fa_utils.py:57] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.9.6: Fast Qwen2_5_Vl patching. Transformers: 4.55.4. vLLM: 0.9.2.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.30. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: Patching vLLM v1 graph capture
# Unsloth: Patching vLLM v0 graph capture
# Unsloth: Vision model detected, setting approx_max_num_seqs to 1
# Unsloth: vLLM loading unsloth/qwen2.5-vl-7b-instruct-unsloth-bnb-4bit with actual GPU utilization = 76.93%
# Unsloth: Your GPU has CUDA compute capability 7.5 with VRAM = 14.74 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 2048. Num Sequences = 1.
# Unsloth: vLLM's KV Cache can use up to 5.21 GB. Also swap space = 0 GB.
# preprocessor_config.json:   0%|          | 0.00/791 [00:00<?, ?B/s]
# INFO 09-16 17:56:17 [config.py:841] This model supports multiple tasks: {'generate', 'embed', 'reward', 'classify'}. Defaulting to 'generate'.
# WARNING 09-16 17:56:17 [config.py:3371] Casting torch.bfloat16 to torch.float16.
# INFO 09-16 17:56:17 [config.py:1472] Using max model len 16384
# WARNING 09-16 17:56:17 [arg_utils.py:1735] Compute Capability < 8.0 is not supported by the V1 Engine. Falling back to V0.
# WARNING 09-16 17:56:17 [arg_utils.py:1556] --enable-prefix-caching is not supported for multimodal models in V0 and has been disabled.
# INFO 09-16 17:56:19 [config.py:2285] Chunked prefill is enabled with max_num_batched_tokens=16384.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'float16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['embed_tokens', 'embedding', 'lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'router', 'visual', 'model.visual.blocks.31.mlp', 'model.visual.blocks.24.attn', 'model.visual.blocks.30.mlp', 'model.visual.blocks.30.attn', 'model.visual.blocks.25.attn', 'model.visual.blocks.29.attn', 'model.visual.blocks.26.attn', 'model.visual.blocks.28.attn', 'model.visual.blocks.19.attn', 'model.visual.blocks.29.mlp', 'model.visual.blocks.28.mlp', 'model.visual.blocks.31.attn', 'model.visual.blocks.25.mlp', 'model.visual.blocks.26.mlp', 'model.visual.blocks.20.attn', 'model.visual.blocks.27.mlp', 'model.visual.blocks.17.attn', 'model.visual.blocks.24.mlp', 'model.visual.blocks.18.attn', 'model.visual.blocks.16.attn', 'model.visual.blocks.11.attn', 'model.visual.blocks.21.mlp', 'model.visual.blocks.20.mlp', 'model.visual.blocks.23.mlp', 'model.visual.blocks.9.attn', 'model.visual.blocks.12.attn', 'model.visual.blocks.23.attn', 'model.visual.blocks.19.mlp', 'model.visual.blocks.22.mlp', 'model.visual.blocks.18.mlp', 'model.visual.blocks.13.attn', 'model.visual.blocks.8.attn', 'model.visual.blocks.11.mlp', 'model.visual.blocks.10.mlp', 'model.visual.blocks.6.attn', 'model.visual.blocks.15.mlp', 'model.visual.blocks.8.mlp', 'model.visual.blocks.9.mlp', 'model.visual.blocks.14.attn', 'model.visual.blocks.5.mlp', 'model.visual.blocks.14.mlp', 'model.visual.blocks.10.attn', 'model.visual.blocks.6.mlp', 'model.visual.blocks.7.mlp', 'model.visual.blocks.5.attn', 'model.visual.blocks.4.mlp', 'model.visual.blocks.16.mlp', 'model.visual.blocks.12.mlp', 'model.visual.blocks.13.mlp', 'model.visual.blocks.2.mlp', 'model.visual.blocks.3.mlp', 'model.visual.blocks.1.attn', 'model.visual.blocks.0.attn', 'model.visual.blocks.4.attn', 'model.visual.blocks.2.attn', 'model.visual.blocks.15.attn', 'model.visual.blocks.3.attn', 'model.visual.blocks.1.mlp', 'model.visual.blocks.17.mlp', 'model.visual.blocks.0.mlp', 'model.visual.blocks.7.attn', 'model.visual.blocks.31.mlp.down_proj'], 'llm_int8_threshold': 6.0}
# INFO 09-16 17:56:19 [llm_engine.py:230] Initializing a V0 LLM engine (v0.9.2) with config: model='unsloth/qwen2.5-vl-7b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/qwen2.5-vl-7b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config={}, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=16384, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=unsloth/qwen2.5-vl-7b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=False, chunked_prefill_enabled=True, use_async_output_proc=True, pooler_config=None, compilation_config={"level":0,"debug_dump_path":"","cache_dir":"","backend":"inductor","custom_ops":[],"splitting_ops":[],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"epilogue_fusion":true,"max_autotune":false,"shape_padding":true,"trace.enabled":false,"triton.cudagraphs":true,"debug":false,"dce":true,"memory_planning":true,"coordinate_descent_tuning":false,"trace.graph_diagram":false,"compile_threads":4,"group_fusion":true,"disable_progress":false,"verbose_progress":true,"triton.multi_kernel":0,"triton.use_block_ptr":true,"triton.enable_persistent_tma_matmul":true,"triton.autotune_at_compile_time":false,"triton.cooperative_reductions":false,"cuda.compile_opt_level":"-O2","cuda.enable_cuda_lto":true,"combo_kernels":false,"benchmark_combo_kernel":true,"combo_kernel_foreach_dynamic_shapes":true,"enable_auto_functionalized_v2":false},"inductor_passes":{},"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"max_capture_size":1,"local_cache_dir":null}, use_cached_outputs=False,
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# generation_config.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# INFO 09-16 17:56:23 [cuda.py:311] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 09-16 17:56:23 [cuda.py:360] Using XFormers backend.
# INFO 09-16 17:56:23 [parallel_state.py:1076] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# INFO 09-16 17:56:23 [model_runner.py:1171] Starting to load model unsloth/qwen2.5-vl-7b-instruct-unsloth-bnb-4bit...
# INFO 09-16 17:56:24 [bitsandbytes_loader.py:499] Loading weights with BitsAndBytes quantization. May take a while ...
# INFO 09-16 17:56:25 [weight_utils.py:292] Using model weights format ['*.safetensors']
# model.safetensors:   0%|          | 0.00/6.90G [00:00<?, ?B/s]
# INFO 09-16 17:57:42 [weight_utils.py:308] Time spent downloading weights for unsloth/qwen2.5-vl-7b-instruct-unsloth-bnb-4bit: 77.113571 seconds
# INFO 09-16 17:57:42 [weight_utils.py:345] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 09-16 17:58:12 [punica_selector.py:19] Using PunicaWrapperGPU.
# INFO 09-16 17:58:13 [model_runner.py:1203] Model loading took 6.7940 GiB and 107.657564 seconds
# video_preprocessor_config.json:   0%|          | 0.00/935 [00:00<?, ?B/s]
# chat_template.json: 0.00B [00:00, ?B/s]
# INFO 09-16 17:59:12 [worker.py:294] Memory profiling takes 57.75 seconds
# INFO 09-16 17:59:12 [worker.py:294] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.77) = 11.34GiB
# INFO 09-16 17:59:12 [worker.py:294] model weights take 6.79GiB; non_torch_memory takes 0.03GiB; PyTorch activation peak memory takes 2.71GiB; the rest of the memory reserved for KV Cache is 1.81GiB.
# INFO 09-16 17:59:12 [executor_base.py:113] # cuda blocks: 2118, # CPU blocks: 0
# INFO 09-16 17:59:12 [executor_base.py:118] Maximum concurrency for 16384 tokens per request: 2.07x
# INFO 09-16 17:59:12 [vllm_utils.py:721] Unsloth: Running patched vLLM v0 `capture_model`.
# INFO 09-16 17:59:12 [model_runner.py:1513] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO 09-16 17:59:20 [model_runner.py:1671] Graph capturing finished in 8 secs, took 0.04 GiB
# INFO 09-16 17:59:20 [vllm_utils.py:728] Unsloth: Patched vLLM v0 graph capture finished in 8 secs.
# INFO 09-16 17:59:21 [llm_engine.py:428] init engine (profile, create kv cache, warmup model) took 68.13 seconds
# Unsloth: Just some info: will skip parsing ['layer_norm1', 'post_layernorm', 'norm2', 'post_attention_layernorm', 'q_norm', 'layer_norm2', 'norm1', 'post_feedforward_layernorm', 'input_layernorm', 'k_norm', 'pre_feedforward_layernorm']
# Unsloth: Just some info: will skip parsing ['layer_norm1', 'cross_attn_input_layernorm', 'post_layernorm', 'cross_attn_post_attention_layernorm', 'post_attention_layernorm', 'q_norm', 'layer_norm2', 'post_feedforward_layernorm', 'input_layernorm', 'k_norm', 'pre_feedforward_layernorm']

# %% [markdown]
# In Unsloth, we share vLLM's weights directly, reducing VRAM usage by > 50%. vLLM also does not yet support LoRA on the vision layers, so we can only add them on the language layers. Vision GRPO still works though!

# %%
model = FastVisionModel.get_peft_model(
    model,
    finetune_vision_layers     = False, # False if not finetuning vision layers
    finetune_language_layers   = True,  # False if not finetuning language layers
    finetune_attention_modules = True,  # False if not finetuning attention layers
    finetune_mlp_modules       = True,  # False if not finetuning MLP layers

    r = 16,           # The larger, the higher the accuracy, but might overfit
    lora_alpha = 16,  # Recommended alpha == r at least
    lora_dropout = 0,
    bias = "none",
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
    use_gradient_checkpointing = "unsloth", # Reduces memory usage
    # target_modules = "all-linear", # Optional now! Can specify a list if needed
)
# Out:
# Unsloth: Making `model.base_model.model.model.language_model` require gradients

# %% [markdown]
# ### Data Prep
# <a name="Data"></a>
#
# `AI4Math/MathVista` is a dataset that involves using images to solve logic and math problems.
#
# For this notebook, we will only use math problems with numeric answers for simpilicity.

# %%
from datasets import load_dataset
from trl import GRPOConfig, GRPOTrainer

dataset = load_dataset("AI4Math/MathVista", split = "testmini")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/testmini-00000-of-00001-725687bf7a1(…):   0%|          | 0.00/142M [00:00<?, ?B/s]
# data/test-00000-of-00002-6b81bd7f7e2065e(…):   0%|          | 0.00/358M [00:00<?, ?B/s]
# data/test-00001-of-00002-6a611c71596db30(…):   0%|          | 0.00/386M [00:00<?, ?B/s]
# Generating testmini split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5141 [00:00<?, ? examples/s]

# %% [markdown]
# We filter the dataset to keep only float or numeric answers:

# %%
def is_numeric_answer(example):
    try:
        float(example["answer"])
        return True
    except:
        return False

dataset = dataset.filter(is_numeric_answer)
# Out:
# Filter:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %% [markdown]
# We also resize the images to be 512 by 512 pixels to make the images managable in context length. We also convert them to RGB so they are compatible for training!

# %%
# Resize to (512, 512)
def resize_images(example):
    image = example["decoded_image"]
    image = image.resize((512, 512))
    example["decoded_image"] = image
    return example
dataset = dataset.map(resize_images)

# Then convert to RGB
def convert_to_rgb(example):
    image = example["decoded_image"]
    if image.mode != "RGB":
        image = image.convert("RGB")
    example["decoded_image"] = image
    return example
dataset = dataset.map(convert_to_rgb)
# Out:
# Map:   0%|          | 0/566 [00:00<?, ? examples/s]
# Map:   0%|          | 0/566 [00:00<?, ? examples/s]

# %% [markdown]
# We then create the conversational template that is needed to collate the dataset for RL:

# %%
# Define the delimiter variables for clarity and easy modification
REASONING_START = "<REASONING>"
REASONING_END = "</REASONING>"
SOLUTION_START = "<SOLUTION>"
SOLUTION_END = "</SOLUTION>"

def make_conversation(example):
    # Define placeholder constants if they are not defined globally
    # The user's text prompt
    text_content = (
        f"{example['question']}, provide your reasoning between {REASONING_START} and {REASONING_END} "
        f"and then your final answer between {SOLUTION_START} and (put a float here) {SOLUTION_END}"
    )

    # Construct the prompt in the desired multi-modal format
    prompt = [
        {
            "role": "user",
            "content": [
                {"type": "image"},  # Placeholder for the image
                {"type": "text", "text": text_content},  # The text part of the prompt
            ],
        },
    ]
    # The actual image data is kept separate for the processor
    return {"prompt": prompt, "image": example["decoded_image"], "answer": example["answer"]}

train_dataset = dataset.map(make_conversation)

# We're reformatting dataset like this because decoded_images are the actual images
# The "image": example["decoded_image"] does not properly format the dataset correctly

# 1. Remove the original 'image' column
train_dataset = train_dataset.remove_columns("image")

# 2. Rename 'decoded_image' to 'image'
train_dataset = train_dataset.rename_column("decoded_image", "image")
# Out:
# Map:   0%|          | 0/566 [00:00<?, ? examples/s]

# %% [markdown]
# Now let's apply the chat template across the entire dataset:

# %%
train_dataset = train_dataset.map(
    lambda example: {
        "prompt": tokenizer.apply_chat_template(
            example["prompt"],
            tokenize = False,
            add_generation_prompt = False,
        )
    }
)
# Out:
# Map:   0%|          | 0/566 [00:00<?, ? examples/s]

# %% [markdown]
# ## Reward functions
#
# We now define some basic formatting rewards functions to see if reasoning starts and ends, and also another to see if the answers were written correctly.

# %%
# Reward functions
import re

def formatting_reward_func(completions,**kwargs):
    import re
    thinking_pattern = f'{REASONING_START}(.*?){REASONING_END}'
    answer_pattern = f'{SOLUTION_START}(.*?){SOLUTION_END}'

    scores = []
    for completion in completions:
        score = 0
        thinking_matches = re.findall(thinking_pattern, completion, re.DOTALL)
        answer_matches = re.findall(answer_pattern, completion, re.DOTALL)
        if len(thinking_matches) == 1:
            score += 1.0
        if len(answer_matches) == 1:
            score += 1.0
        scores.append(score)
    return scores


def correctness_reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    answer_pattern = f'{SOLUTION_START}(.*?){SOLUTION_END}'

    responses = [re.findall(answer_pattern, completion, re.DOTALL) for completion in completions]
    q = prompts[0]

    print('-'*20, f"Question:\n{q}", f"\nAnswer:\n{answer[0]}", f"\nResponse:{completions[0]}")
    return [
        2.0 if len(r)==1 and a == r[0].replace('\n','') else 0.0
        for r, a in zip(responses, answer)
    ]

# %% [markdown]
# Here is the first example prompt in the dataset

# %%
train_dataset[0]["prompt"]
# Out:
# "<|im_start|>system\nYou are a helpful assistant.<|im_end|>\n<|im_start|>user\n<|vision_start|><|image_pad|><|vision_end|>When a spring does work on an object, we cannot find the work by simply multiplying the spring force by the object's displacement. The reason is that there is no one value for the force-it changes. However, we can split the displacement up into an infinite number of tiny parts and then approximate the force in each as being constant. Integration sums the work done in all those parts. Here we use the generic result of the integration.\r\n\r\nIn Figure, a cumin canister of mass $m=0.40 \\mathrm{~kg}$ slides across a horizontal frictionless counter with speed $v=0.50 \\mathrm{~m} / \\mathrm{s}$. It then runs into and compresses a spring of spring constant $k=750 \\mathrm{~N} / \\mathrm{m}$. When the canister is momentarily stopped by the spring, by what distance $d$ is the spring compressed?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>\n"

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Now let's try the model on the hundredth sample of the train dataset without training.

# %%
from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 1.0,
    top_k = 50,
    max_tokens = 1024,
)

outputs = model.fast_generate(
    {
        "prompt": train_dataset[100]["prompt"],
        "multi_modal_data": {"image": train_dataset[100]["image"]}
    },
    sampling_params,
)
print(outputs[0].outputs[0].text)
# Out:
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
#  addCriterion
# <solution>
# <solution>1</solution>

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
#
# Now set up the `GRPO` Trainer and all configurations! Note we actually enable `GSPO` as well!

# %%
from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "adamw_8bit",
    logging_steps = 1,
    log_completions = False,
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 2, # Increase to 4 for smoother training
    num_generations = 4, # Decrease if out of memory
    max_prompt_length = 1024,
    max_completion_length = 1024,
    # num_train_epochs = 2, # Set to 1 for a full training run
    max_steps = 60,
    save_steps = 60,
    max_grad_norm = 0.1,
    report_to = "none", # Can use Weights & Biases
    output_dir = "outputs",

    # Below enables GSPO:
    importance_sampling_level = "sequence",
    mask_truncated_completions = False,
    loss_type = "dr_grpo",
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 4

# %% [markdown]
# And let's run the trainer! If you scroll up, you'll see a table of rewards. The goal is to see the `reward` column increase!
#
# You might have to wait 150 to 200 steps for any action. You'll probably get 0 reward for the first 100 steps. Please be patient!
#
# | Step | Training Loss | reward    | reward_std | completion_length | kl       |
# |------|---------------|-----------|------------|-------------------|----------|
# | 1    | 0.000000      | 0.125000  | 0.000000   | 200.000000        | 0.000000 |
# | 2    | 0.000000      | 0.072375  | 0.248112   | 200.000000        | 0.000000 |
# | 3    | 0.000000      | -0.079000 | 0.163776   | 182.500000        | 0.000005 |

# %%
trainer = GRPOTrainer(
    model = model,
    args = training_args,
    # Pass the processor to handle multimodal inputs
    processing_class = tokenizer,
    reward_funcs = [
        formatting_reward_func,
        correctness_reward_func,
    ],
    train_dataset = train_dataset,
)

trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 566 | Num Epochs = 1 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 4 | Gradient accumulation steps = 2
# \        /    Data Parallel GPUs = 1 | Total batch size (4 x 2 x 1) = 8
#  "-____-"     Trainable parameters = 40,370,176 of 8,332,536,832 (0.48% trained)
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What is the highest value on the X axis?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 30
# Response: addCriterion
# <solution>
# The highest value on the X-axis, as shown in the image, is 30 microliters.
#
# Therefore, the final answer is:
#
# <REASONING>
# The highest value label on the bottom horizontal axis (X-axis) is "30," which represents the maximum measurement or quantity marked on this axis.
# </REASONING>
# <SOLUTION>
# 30.0
# </SOLUTION>
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='50' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50/60 1:39:48 < 20:47, 0.01 it/s, Epoch 0.17/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>rewards / formatting_reward_func / mean</th>
#       <th>rewards / formatting_reward_func / std</th>
#       <th>rewards / correctness_reward_func / mean</th>
#       <th>rewards / correctness_reward_func / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>-0.027500</td>
#       <td>0.750000</td>
#       <td>0.957427</td>
#       <td>28.125000</td>
#       <td>3.000000</td>
#       <td>89.000000</td>
#       <td>0.000000</td>
#       <td>28.125000</td>
#       <td>3.000000</td>
#       <td>89.000000</td>
#       <td>0.000113</td>
#       <td>0.500000</td>
#       <td>0.925820</td>
#       <td>0.250000</td>
#       <td>0.707107</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-0.124900</td>
#       <td>1.125000</td>
#       <td>1.353913</td>
#       <td>153.625000</td>
#       <td>4.000000</td>
#       <td>329.000000</td>
#       <td>0.000000</td>
#       <td>153.625000</td>
#       <td>4.000000</td>
#       <td>329.000000</td>
#       <td>0.000035</td>
#       <td>0.875000</td>
#       <td>0.991031</td>
#       <td>0.250000</td>
#       <td>0.707107</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>-0.035400</td>
#       <td>0.250000</td>
#       <td>0.500000</td>
#       <td>105.750000</td>
#       <td>6.000000</td>
#       <td>279.000000</td>
#       <td>0.000000</td>
#       <td>105.750000</td>
#       <td>6.000000</td>
#       <td>279.000000</td>
#       <td>0.000016</td>
#       <td>0.250000</td>
#       <td>0.462910</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>-0.022100</td>
#       <td>1.125000</td>
#       <td>1.327350</td>
#       <td>182.000000</td>
#       <td>4.000000</td>
#       <td>591.000000</td>
#       <td>0.000000</td>
#       <td>182.000000</td>
#       <td>4.000000</td>
#       <td>591.000000</td>
#       <td>0.000019</td>
#       <td>0.875000</td>
#       <td>0.991031</td>
#       <td>0.250000</td>
#       <td>0.707107</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>-0.043700</td>
#       <td>0.625000</td>
#       <td>0.478714</td>
#       <td>236.750000</td>
#       <td>6.000000</td>
#       <td>967.000000</td>
#       <td>0.000000</td>
#       <td>236.750000</td>
#       <td>6.000000</td>
#       <td>967.000000</td>
#       <td>0.000022</td>
#       <td>0.625000</td>
#       <td>0.916125</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>-0.057600</td>
#       <td>1.125000</td>
#       <td>0.750000</td>
#       <td>135.750000</td>
#       <td>4.000000</td>
#       <td>238.000000</td>
#       <td>0.000000</td>
#       <td>135.750000</td>
#       <td>4.000000</td>
#       <td>238.000000</td>
#       <td>0.000018</td>
#       <td>1.125000</td>
#       <td>0.991031</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>-0.047000</td>
#       <td>0.250000</td>
#       <td>0.500000</td>
#       <td>24.625000</td>
#       <td>3.000000</td>
#       <td>134.000000</td>
#       <td>0.000000</td>
#       <td>24.625000</td>
#       <td>3.000000</td>
#       <td>134.000000</td>
#       <td>0.000120</td>
#       <td>0.250000</td>
#       <td>0.707107</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>-0.071000</td>
#       <td>1.625000</td>
#       <td>0.750000</td>
#       <td>113.000000</td>
#       <td>4.000000</td>
#       <td>258.000000</td>
#       <td>0.000000</td>
#       <td>113.000000</td>
#       <td>4.000000</td>
#       <td>258.000000</td>
#       <td>0.000055</td>
#       <td>1.375000</td>
#       <td>0.916125</td>
#       <td>0.250000</td>
#       <td>0.707107</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>-0.040100</td>
#       <td>0.750000</td>
#       <td>0.645497</td>
#       <td>128.375000</td>
#       <td>6.000000</td>
#       <td>320.000000</td>
#       <td>0.000000</td>
#       <td>128.375000</td>
#       <td>6.000000</td>
#       <td>320.000000</td>
#       <td>0.005724</td>
#       <td>0.500000</td>
#       <td>0.755929</td>
#       <td>0.250000</td>
#       <td>0.707107</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>-0.023400</td>
#       <td>0.250000</td>
#       <td>0.500000</td>
#       <td>209.500000</td>
#       <td>3.000000</td>
#       <td>993.000000</td>
#       <td>0.000000</td>
#       <td>209.500000</td>
#       <td>3.000000</td>
#       <td>993.000000</td>
#       <td>0.007705</td>
#       <td>0.250000</td>
#       <td>0.707107</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>-0.102400</td>
#       <td>0.625000</td>
#       <td>0.978714</td>
#       <td>86.875000</td>
#       <td>3.000000</td>
#       <td>253.000000</td>
#       <td>0.000000</td>
#       <td>86.875000</td>
#       <td>3.000000</td>
#       <td>253.000000</td>
#       <td>0.003192</td>
#       <td>0.625000</td>
#       <td>0.916125</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>-0.137400</td>
#       <td>0.625000</td>
#       <td>0.767389</td>
#       <td>117.250000</td>
#       <td>3.000000</td>
#       <td>280.000000</td>
#       <td>0.000000</td>
#       <td>117.250000</td>
#       <td>3.000000</td>
#       <td>280.000000</td>
#       <td>0.004955</td>
#       <td>0.625000</td>
#       <td>0.744024</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.002300</td>
#       <td>0.125000</td>
#       <td>0.250000</td>
#       <td>71.125000</td>
#       <td>3.000000</td>
#       <td>262.000000</td>
#       <td>0.000000</td>
#       <td>71.125000</td>
#       <td>3.000000</td>
#       <td>262.000000</td>
#       <td>0.001650</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>-0.052400</td>
#       <td>0.750000</td>
#       <td>0.645497</td>
#       <td>310.250000</td>
#       <td>6.000000</td>
#       <td>779.000000</td>
#       <td>0.000000</td>
#       <td>310.250000</td>
#       <td>6.000000</td>
#       <td>779.000000</td>
#       <td>0.000288</td>
#       <td>0.500000</td>
#       <td>0.755929</td>
#       <td>0.250000</td>
#       <td>0.707107</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>505.000000</td>
#       <td>4.000000</td>
#       <td>995.000000</td>
#       <td>0.000000</td>
#       <td>505.000000</td>
#       <td>4.000000</td>
#       <td>995.000000</td>
#       <td>0.000023</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>-0.186000</td>
#       <td>0.375000</td>
#       <td>0.750000</td>
#       <td>214.500000</td>
#       <td>3.000000</td>
#       <td>565.000000</td>
#       <td>0.000000</td>
#       <td>214.500000</td>
#       <td>3.000000</td>
#       <td>565.000000</td>
#       <td>0.003402</td>
#       <td>0.375000</td>
#       <td>0.744024</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>-0.085200</td>
#       <td>1.000000</td>
#       <td>1.154701</td>
#       <td>118.625000</td>
#       <td>6.000000</td>
#       <td>268.000000</td>
#       <td>0.000000</td>
#       <td>118.625000</td>
#       <td>6.000000</td>
#       <td>268.000000</td>
#       <td>0.000327</td>
#       <td>1.000000</td>
#       <td>1.069045</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>-0.041400</td>
#       <td>0.750000</td>
#       <td>0.500000</td>
#       <td>88.000000</td>
#       <td>6.000000</td>
#       <td>245
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Subtract all yellow metallic balls. Subtract all small yellow shiny things. How many objects are left?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 8
# Response: addCriterion
# <solution>
# There are two objects that are small yellow shiny objects:
# 1. A small yellow metallic ball
# 2. A small yellow metallic cylinder
#
# Subtracting these two objects leaves us with the following objects:
#
# 3. A large blue cube
# 4. A small blue cube
# 5. A small blue metallic cube
# 6. A purple cylinder
# 7. A purple metallic cylinder
# 8. A small gray metallic sphere
# 9. A small gray matte sphere
# 10. A small cyan cube
#
# So, there are 10 objects left.
#
# </solution>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What is the highest accuracy reported in the whole chart?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 8
# Response: addCriterion
# <solution>
# </solution>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What is the value of the largest bar?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 10000
# Response: addCriterion
# ;text
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What is the age gap between these two people in image?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 16
# Response: addCriterion
#
#  addCriterion
#
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What is the age gap between these two people in image?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 12
# Response: addCriterion
# 感激
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>For Group C, in which week is the cumulative increase in weight , the highest?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 3
# Response: addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
# styleType
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>An author recorded how many words she wrote in the past 3 days. How many words in total did the author write on Thursday and Friday? (Unit: words), provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 679
# Response: addCriterion
# The image provided is a table with the heading "Words written" and a structure where it lists the number of words written on different days, specifically Wednesday, Thursday, and Friday. The table shows the following entries:
#
# - Wednesday: 407 words
# - Thursday: 374 words
# - Friday: 305 words
#
# To determine the total number of words written on Thursday and Friday, we need to add the number of words written on each of those days.
#
# Here are the details:
#
# <REASONING>
# Step 1: Identify the number of words written on Thursday.
# Step 2: Identify the number of words written on Friday.
# Step 3: Add these two numbers together to get the total.
#
# Number of words written on Thursday = 374
# Number of words written on Friday = 305
# Total words written on Thursday and Friday = 374 + 305
#
# </REASONING>
#
# Now, let's perform the addition:
#
# <REASONING>
# 374 + 305 = 679
# </REASONING>
#
# Therefore, the total number of words written on Thursday and Friday is 679.
#
# <SOLUTION>679</SOLUTION>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>How many items sold more than 3 units in at least one store?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 7
# Response: addCriterion
# <solution>
# There are six items sold more than 3 units in at least one store based on the above chart.
#
# 1..Items in both stores цена 1 and price <3.
# 2.Deputy и convict.
# 3.Brave priced at record 1 and recruit
# 4.Crook priced at price record 1 and recruit
# 5.Crook priced at price record 1 and recruit
# 6.Breeze priced at record 1 and calf
# 7.Above priced at price record 1 and recruit
# 8.Boom priced at record 1 and calf
# </solution>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>As shown in the figure, E is any point in ▱ABCD, if S~quadrilateral ABCD~ = 6.0, then the area of ​​the shaded part in the figure is (), provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 3
# Response: addCriterion
#
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What is the age gap between these two people in image?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 28
# Response: addCriterion
#
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What is the age gap between these two people in image?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 22
# Response: addCriterion
# .DAO
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Lines $l$, $m$, and $n$ are perpendicular bisectors of $\triangle PQR$ and meet at $T$. If $TQ = 2x$, $PT = 3y - 1$, and $TR = 8$, find $z$., provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 3
# Response: addCriterion
#
#  addCriterion
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What is the total value of the More bar?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 52
# Response: addCriterion
# <solution>
# <REASONING>
# The total value of the "More" bar can be found by adding the percentages for "Men" and "Women" under the "More" category.
#
# For men, the percentage is 46.
# For women, the percentage is 58.
#
# Adding these together:
# 46 + 58 = 104
# </REASONING>
#
# <SOLUTION>
# 104.0
# </SOLUTION>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>如图，在△ABC中，点D是△ABC的内心，连接DB，DC，过点D作EF∥BC分别交AB、AC于点E、F，若BE+CF＝8，则EF的长度为（）, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 8
# Response: addCriterion
#
#  addCriterion
#
# ��
# ��
#
# ��
#
# ��
#
#
# ��
#
#
#
# ��
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>For how many years that the percentage value over 4?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 6
# Response: addCriterion
# 六年
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Subtract all tiny purple shiny cubes. Subtract all large purple balls. How many objects are left?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 9
# Response: addCriterion
# <solution requested
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>what is the total volume of the measuring cup?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 1000
# Response: addCriterion
# The image shows a kitchen counter with a large glass mixing bowl containing flour, a carton of eggs, and a milk jug on a wooden cutting board. There is a white measuring cup labeled with liters and milliliters for volume measurement.
#
# To determine the total volume of the measuring cup, we need to look at its scale. The cup is marked with measurements in liters and milliliters. Additionally, there is a spoon resting in the measuring cup, which may serve as a guide for estimation.
#
# <REASONING>
# 1. The measuring cup is marked without a full liter measurement. It starts at 0 milliliters and increases in increments that likely correspond to increments in liters.
# 2. Observing the highest clearly marked increment, it appears closest to 1 liter (1000 milliliters).
# 3. Since the increments seem to be standard milliliter marks, with visible discontinuities possibly due to design, I can infer the cup's largest visible measurement.
# 4. The markings seem to jump linearly as expected in standard measurement tools, suggesting 1 liter as the total volume.
#
# </REASONING>
# <SOLUTION>
# 1000.00 </SOLUTION>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Colton wants to buy 1+3/10 kilograms of English muffins. How much will he spend? (Unit: $), provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 10.4
# Response: addCriterion
# <sampling_method>
# Simple workings</sampler
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Phenylalanine (Phe, 5) is a naturally occurring amino acid. What is the energy of interaction between its phenyl group and the electric dipole moment of a neighbouring peptide group? Take the distance between the groups as $4.0 \mathrm{~nm}$ and treat the phenyl group as a benzene molecule. The magnitude of the dipole moment of the peptide group is $\mu=1.3 \mathrm{D}$ and the polarizability volume of benzene is $\alpha^{\prime}=1.04 \times 10^{-29} \mathrm{~m}^3$.
# , provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# -4.3
# Response: addCriterion
# The image provided is the structural formula of Phenylalanine, a naturally occurring amino acid. The structural formula shows the presence of a benzene ring directly bonded to a central carbon atom, which also contains a nitrogen atom in an amide group. The pKa values associated with the structure indicate that the amine group has a pKa value of 9.2 and the carboxyl group has a pKa value of 2.15.
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Some friends compared the sizes of their stuffed animal collections. What is the median of the numbers?', provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 9
# Response: addCriterion
# <sdata>
# <sfields>
# <sfield><sname> st</sname><slabel>0<slabel></sfield><sfield><sname>ed</sname><slabel>0<slabel></sfield><sfield><sname>in</sname><slabel>1<slabel></sfield><sfield><sname>gr</sname><slabel>1<slabel></sfield><sfield><sname>a</sname><slabel>1<slabel></sfield><sfield><sname>r</sname><slabel>1<slabel></sfield><sfield><sname>珊瑚</sname><slabel>1<slabel></sfield><sfield><sname>原</sname><slabel>1<slabel></sfield><sfield><sname>s</sname><slabel>0<slabel></slabel></sfield>
# </sfields>
# <srows>
# <srow><sval>0<sval><sval>sth</sval><sval> essere</sval><sval> Sicilia</sval><sval>Egeria</sval><sval>Gronda</sval><sval>Zwittcrafted</sval><sval>relijke</sval><sval>KK</sval><sval>yp</sval></srow><srow><sval>1<sval><sval>pa</sval><sval>Gutene</sval><sval>Dueur</sval><sval>Nore</sval><sval>Lug</sval><sval>Okito</sval><sval>Kace</sval><sval>IchK</sval><sval>Rip Tre</sval></srow><srow><sval>2<sval><sval>ir</sval><sval>H</sval><sval>ha</sval><sval>hi</sval><sval>py</sval><sval>Olitty</sval><sval>Magic</sval><sval>SStacks</sval><sval>rifts</sval></srow><srow><sval>3<sval><sval>est</sval><sval>(14.</sval><sval>Ro</sval><sval>myonm</sval><sval>Hy</sval><sval>Re</sval><sval>allk</sval><sval>ca</sval><sval>plD</sval></srow><srow><sval>4<sval><sval>cha</sval><sval>forafas</sval><sval>O</sval><sval>Mong</sval><sval>V</sval><sval)oAo</sval><sval>Cook</sval><sval>He</sval><sval>ysho</sval></srow><srow><sval>5<sval><sval>nu</sval><sval>pect</sval><sval>la</sval><sval>In</sval><sval>Gal</sval><sval>Ly</sval><sval>Psy</sval><sval>diff</sval><sval>part</sval></srow><srow><sval>6<sval><sval>k</sval><sval>prenef</sval><sval>les</sval><sval>or</sval><sval>be</sval><sval>Essi</sval><sval>varb</sval><sval>Ga</sval><sval>Herren</sval></srow><srow><
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Subtract all large rubber spheres. Subtract all big shiny cylinders. How many objects are left?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 4
# Response: addCriterion
# <solutions>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>$a=14, b=48,$ and $c=50$ find $cosA$, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 0.96
# Response: addCriterion
# 好象
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What is the sum of accuracies of the algorithm liver for all the datasets?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 24
# Response: addCriterion
# <solution>
# <REASONING>
# To find the sum of the accuracies of the "liver" algorithm for all datasets, we need to add the values of each column corresponding to the "liver" algorithm.
#
# The datasets are:
# - desert
# - debt
# - bee
# - saw
# - wool
#
# The corresponding accuracy values for the "liver" algorithm are:
# - desert: 2
# - debt: 5
# - bee: 3
# - saw: 7
# - wool: 7
#
# Now, we add these values:
# 2 (desert) + 5 (debt) + 3 (bee) + 7 (saw) + 7 (wool)
#
# Let's calculate it:
# 2 + 5 = 7
# 7 + 3 = 10
# 10 + 7 = 17
# 17 + 7 = 24
#
# Final answer:
# <REASONING>24</REASONING>
# </SOLUTION>
# <REASONING>24.0</REASONING>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Subtract all large purple spheres. Subtract all small gray things. How many objects are left?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 9
# Response: addCriterion
# <solution>
# From the image, there are no large purple spheres.
#
# The small gray objects in the image include:
# - a small gray cylinder.
#
# After removing these, the remaining objects are:
# - 1 small blue cube
# - 1 small red metallic sphere
# - 1 large blue metallic sphere
# - 1 large gray metallic cube
# - 1 large cyan cube
# - 1 large brown sphere
# - 1 large brown cylinder
# - 1 large green metallic cube
# - 1 small red cylinder
#
# Counting these objects:
#
# 1 small blue cube
# 1 small red metallic sphere
# 1 large blue metallic sphere
# 1 large gray metallic cube
# 1 large cyan cube
# 1 large brown sphere
# 1 large brown cylinder
# 1 large green metallic cube
# 1 small red cylinder
#
# <REASONING>
# There are a total of 9 objects left.
# </REASONING>
# <SOLUTION>9.0</SOLUTION>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What is the sum of all the values in the ruling group?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 12
# Response: addCriterion
# The image provided is a horizontal bar chart with two variables differentiated by color: tin (red) and ace (blue). The chart has a title "Title" and the y-axis labels include "virus," "vigor," "ruling," "ninety," "calf," "flower," and "toilet."
#
# <REASONING>
# To find the sum of all the values in the "ruling" group:
# 1. Identify the values for tin (red) and ace (blue) under "ruling."
# 2. The red (tin) bar for "ruling" extends to approximately 8 on the x-axis.
# 3. The blue (ace) bar for "ruling" extends to approximately 9 on the x-axis.
# 4. Add these two values together to get the total sum for the "ruling" group.
#
# </REASONING>
# <SOLUTION>
# The sum of all the values in the "ruling" group is 17.
# </SOLUTION>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>如图，AC，BD是菱形ABCD的对角线，BH⊥AD于点H，若AC＝4，BD＝3，则BH的长为（）, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 2.4
# Response: addCriterion
# 因为在菱形ABCD中，对角线AC和BD互相垂直且平分对方，所以三角形ABC是直角三角形且H是AD边上的高。电量AC和BD分别是4和3，可以利用勾股定理算出菱形的边长为<REASONING>
# <LM1>=√(3²+4²)=5。进而可以算出平行四边形的面积为<REASONING>
# <LM2>=1/2*AC*BD=6。于是我们有<REASONING>
# <LM3>=1/2*a*l=6。l迎着是解设题所需的要找的斜线AD长，a则为直角边BH，l为斜边(/）。
#
# 于是我们能够求出 BH长度为<REASONING>
# <LM4>=BH=a*√(5*6/5*5)=12/5*(3/5*5)≈2.4
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What is the age gap between these two people in image?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 19
# Response: addCriterion
#
#  addCriterion
# The image provided shows two individuals sitting on a stage with an American flag in the background. One appears to be an older woman wearing a dark outfit and the other appears to be a younger individual wearing a light blue blazer.
#
# <REASONING>
# To estimate the age gap:
# 1. The older woman seems to be in her 60s or 70s based on her attire and visible features.
# 2. The younger individual looks to be in her 30s or 40s based on her attire and overall appearance.
#
# <REASONING>
# Using these observations, the age gap appears to be approximately 30 years.
#
# </SOLUTION>
# (SOLUTION)
# The age gap between the two individuals in the image is approximately 30 years.
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What is the fraction of females facing the camera?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 0.8
# Response: addCriterion
# <solution>
# Step 1: Identify the number of females in the image. In this case, there are 5 females.
# Step 2: Count how many females are facing the camera fully or partially. All the individuals in the image are facing the camera.
# Step 3: Calculate the fraction.
#
# 5 females facing the camera out of 5 total individuals is 5/5.
#
# Therefore, the fraction of females facing the camera is 1.
#
# <REASONING>This reasoning accounts for the given image where all individuals appear to be facing the camera. There is no partial content affecting the visibility, such as senior citizens partially buried behind others or pen mat pages creating a angled back view. Hence, it is clear from the analysis that this fraction calculation adheres to the image's perspective.</REASONING>
#
# <SOLUTION>1.0</SOLUTION>
# </agent>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>At time $t=0$ a tank contains $Q_0 \mathrm{lb}$ of salt dissolved in 100 gal of water; see Figure 2.3.1. Assume that water containing $\frac{1}{4} \mathrm{lb}$ of salt/gal is entering the tank at a rate of $r \mathrm{gal} / \mathrm{min}$ and that the well-stirred mixture is draining from the tank at the same rate. Set up the initial value problem that describes this flow process. By finding the amount of salt $Q(t)$ in the tank at any time, and the limiting amount $Q_L$ that is present after a very long time, if $r=3$ and $Q_0=2 Q_L$, find the time $T$ after which the salt level is within $2 \%$ of $Q_L$. , provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 130.4
# Response: addCriterion
#
#  addCriterion
#
#  addCriterion
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#
#  addCriterion
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Calculate the missing value., provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 1
# Response: addCriterion
# Calculate the missing value
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What is the degree of this function?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 3
# Response: addCriterion
# The graph provided shows a function with particular characteristics that can be analyzed to determine its degree.
#
# <REASONING>
# 1. **Shape Analysis**: The graph appears to be a curve that resembles the graph of a polynomial function. Specifically, it looks like a cubic polynomial, which typically has a distinct S-shape.
#
# 2. **Extrapolation and Slope**: If we consider the degree of the function, a cubic polynomial typically has a graph that changes direction twice (from concave down to concave up and vice versa). By looking at the point of inflection, which is where the function changes from being concave-down to concave-up, we can infer it's a cubic function.
#
# 3. **Asymptotic Behavior**: The function approaches linear behavior quite close to the x-axis around the points where the graph starts and ends within the visible range. This is consistent with a cubic polynomial, as high-degree polynomials tend to behave linearly away from their roots.
#
# <REASONING>
#
# Between the visible aspects of the graph, the visual and graphical features align with what we typically see with cubic functions.
#
# Based on the analysis, the function is likely a cubic polynomial.
#
# <SOLUTION>
# 3.0
# </SOLUTION>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>How many people in the image were born after the end of World War II?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 4
# Response: addCriterion
# Let's analyze the image step by step:
#
# 1. The image shows four men standing together. They appear to be older, which could suggest they are middle-aged or older adults.
# 2. The event they are in seems to be a formal meeting or greeting, indicated by the flags and the formal attire.
# 3. None of the men appear to be elderly, but their faces specifically suggest they were likely born after the end of World War II (which ended in 1945).
#
# Considering these observations, it appears likely that all four individuals were born after the end of World War II.
#
# <REASONING>
# The men in the image appear to be middle-aged or older adults who cannot be recognized as elderly. Based on the general appearance and the event depicted, they seem to have been born after 1945.
# </REASONING>
#
# <SOLUTION>
# 4.0
# </SOLUTION>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Rectangle ABCD is subdivided into two identical square regions, as in the figure above. If the area of each square is 9, what is the perimeter of ABCD?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 18
# Response: addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  自动生成
#  <REASONING>
# First, we need to determine the side length of the square regions. Since the area of each square is 9, we can find the side length by taking the square root of the area:
# \[ \text{Side length} = \sqrt{9} = 3 \]
#
# Next, we observe that the figure shows two squares arranged side by side against the longer sides of the rectangle. Therefore, the length of the rectangle (ABCD) will be equal to the sum of the side lengths of these squares:
# \[ \text{Length of ABCD} = 3 + 3 = 6 \]
#
# Similarly, the width of the rectangle will be equal to the side length of the squares:
# \[ \text{Width of ABCD} = 3 \]
#
# Now we can calculate the perimeter of the rectangle. The perimeter \(P\) of a rectangle can be found using the formula:
# \[ P = 2 \times (\text{Length} + \text{Width}) \]
#
# Substituting the length and width we found:
# \[ P = 2 \times (6 + 3) = 2 \times 9 = 18 \]
#
# </REASONING>
# <SOLUTION>
# The perimeter of rectangle ABCD is 18.
# </SOLUTION>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What is cumulative increase in weight ( in grams) for "GROUP A" in third week ( give an approximate value) ?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 400
# Response: addCriterion
# <solution getSolutionFromInitialization>
# To determine the cumulative increase in weight for "GROUP A" in the third week, we need to identify the relevant data point on the graph for "GROUP A."
#
# 1. locate the graph: The graph is labeled with different experimental groups and control groups, and we are interested in "GROUP A," which is marked as "42% POWDER."
#
# 2. find the appropriate week: We need to focus on the third week (labeled as "3" on the x-axis).
#
# 3. read the value: At the third week, the cumulative increase in weight for "GROUP A" appears to be approximately 300 grams.
#
# Therefore, the cumulative increase in weight for "GROUP A" in the third week is <SOLUTION> approximately 300 grams </SOLUTION>.
#  </solution>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Find the value of the square in the figure., provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 2
# Response: addCriterion
# <REASONING>
# From the given equations:
# 1. The value of the blue ellipse plus the value of the red square is 5.
# 2. The value of the yellow triangle plus the value of the yellow triangle is 8, meaning the value of one yellow triangle is 4.
# 3. The value of the blue ellipse plus the value of the yellow triangle is 7.
# We can deduce that the value of the blue ellipse is 3 (since 7-4=3).
#
# Now substituting the value of the blue ellipse to the first equation:
# 3 (blue ellipse) + value of the red square = 5
# Therefore, the value of the red square is 2.
#
# </REASONING>
# <SOLUTION>
# 2.0
# </SOLUTION>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Move the ruler to measure the length of the nail to the nearest inch. The nail is about (_) inches long., provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 2
# Response: addCriterion
# <sentence>Multiply this float by
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Subtract all big matte balls. Subtract all green rubber objects. How many objects are left?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 7
# Response: addCriterion
# <SUMMARY>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>At which Episode ID does the Retroformer attain its peak Success rate (%)?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 4.0
# Response: addCriterion
# At which Episode ID does the Retroformer attain its peak Success rate (%)?
#
# <REASONING>
# The graph shows the success rate of three systems over different episode IDs on the HotPotQA dataset, with 100 distractor tasks involved. The system labeled "Retroformer+4-shot sampling" is the subject of our interest.
#
# - At Episode ID 0, the Retroformer's success rate starts at around 35%.
# - As the episode ID increases, the success rate increases steadily for the Retroformer as well.
# - At Episode ID 4, the Retroformer's success rate reaches its highest point before the graph ends, which appears to be around 57%.
#
# Therefore, the Retroformer attains its peak success rate at Episode ID 4.
#
# </REASONING>
#
# <SOLUTION>
# 4.0
# </SOLUTION>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>在Rt△ABC中，∠C＝90°，若AC＝6，BC＝8，则cosA的值为（）, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 0.6
# Response: addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
# GuidId
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What is the lowest accuracy reported in the whole chart?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 1
# Response: addCriterion
# <REASONING>
# To determine the lowest accuracy reported in the whole chart, we need to identify the smallest bar segment in the given stacked bar chart.
#
# 1. **Analyze the categories and their components**:
#    - The chart shows three categories: "deputy," "flag," and "blast."
#    - Each category is divided into three segments representing different "datasets."
#    - The datasets are shown by different colors, such as "arrest" in green, "breed" in pink, and "potato" in purple.
#
# 2. **Examine each category**:
#    - **Deputy**: The smallest segment is the green "arrest" dataset, which appears to be the smallest among the three segments.
#    - **Flag**: The smallest segment is the green "arrest" dataset in the first part of the "flag" bar.
#    - **Blast**: The smallest segment is the pink "breed" dataset in the lower part of the "blast" bar.
#
# 3. **Determine the smallest segment**:
#    - Compare the heights of the green "arrest" datasets:
#      - Deputy: Approximately 2 units.
#      - Flag: Approximately 4 units.
#      - Blast: Approximately 2 units (upper part).
#
#    The smallest segment is the green "arrest" dataset in the "deputy" category, which is approximately 2 units.
#
# </REASONING>
#
# <SOLUTION>
# (2.0)
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Which number is missing?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 4
# Response: addCriterion
# Sure, let's analyze the given pattern in the image step by step to determine the missing number.
#
# 1. **Identify the pattern**: The numbers in the image are distributed in a specific pattern. Each number appears to be a result of a mathematical operation, but we need to figure out the consistent operation.
#
# 2. **Identify the relationships**: Let's look at the relationships between the numbers:
#    - The number 18 is adjacent to 9 and 2. If we consider the operation involving 9 and 2, we can see that multiplying them gives 18: \(9 \times 2 = 18\).
#    - Next, we look at the number 6 and division. If we divide 36 by 6, we get 6, but that's not clear why 6 is directly adjacent to 6 without seeming to follow a simple multiplication.
#    - The central number seems to be the focal point. Let's consider the combination of 6 and 12 and subtract the central number: \(12 - 6 = 6\).
#    - Now, seeing the pattern with addition, the central number 2 plus 1 (assuming the position adds systematically) is \(2 + 1 + 1 = 4\) (where systematic mean adding rule, it will be linear but I run into divides add Mọi).
#
# 3. **Construction**: It seems, instead assume at center first, traditional center mix with adding result become central add here 2 or 5 not resulting with all angles added 9.
#
# Relectric -> based upon test:
# - Given 6 and 12 to be derived from simple multiplying: thus 18 → finding next one multiply.
#
# Based on these cycles, the next:
#
# <REASONING>
# The central number 7 leads; next multiply should follow.
# </REASONING>
#
# Thus:
#
# <SOLUTION>
# The missing number is likely:
# 7
# </SOLUTION>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>The teachers at an elementary school counted how many desks they had in their classrooms. What is the median of the numbers?', provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 32
# Response: addCriterion
# OK
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What is the value of the smallest individual bar in the whole chart?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# -8
# Response: addCriterion
# <solution>
# The chart is a horizontal bar chart with three categories: candle, slug, and prose. Each category has a set of bars with positive and negative values.
#
# <REASONING>
# Let's review the bars for each category:
#
# 1. The 'candle' category has one bar that extends to the negative side, reaching approximately -8.0.
# 2. The 'slug' category has two bars: one reaching approximately 5.0 (positive) and another reaching approximately -3.0 (negative).
# 3. The 'prose' category has one bar reaching approximately 9.0 (positive).
#
# The smallest value in the 'candle' category is approximately -8.0, which is the lowest among all categories and bars.
#
# </REASONING>
# (<SOLUTION> -8.0 </SOLUTION>)
# </solution>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Move the ruler to measure the length of the pencil to the nearest inch. The pencil is about (_) inches long., provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 3
# Response: addCriterion
# The image shows a ruler placed below a pencil. The ruler is marked in inches with measurements from 0 to 6. The pencil extends from the 2-inch mark to the 3-inch mark on the ruler. To measure the pencil's length to the nearest inch, we need to consider where the end of the pencil falls on the ruler.
#
# <REASONING>
# 1. The ruler indicates that the pencil's length starts at 2 inches and extends beyond the 3-inch mark.
# 2. Since the pencil's length extends past the 3-inch mark but does not reach the 4-inch mark, we should round the measurement to the nearest whole number.
# 3. Given that the pencil's length extends beyond the 3-inch mark, it is closer to 3 inches than 2 inches.
#
# </REASONING>
#
# <SOLUTION>
# 3.0 </SOLUTION>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>How many cinnamon rolls are there?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 20
# Response: addCriterion
# The image shows two plates, each with cinnamon rolls on them. Let's count the cinnamon rolls in each plate step-by-step.
#
# <REASONING>
# 1. In the first plate on the left, there are 8 cinnamon rolls.
# 2. In the second plate on the right, there are also 8 cinnamon rolls.
# 3. Adding the cinnamon rolls from both plates gives us the total count:
#
# 8 cinnamon rolls (left plate) + 8 cinnamon rolls (right plate) = 16 cinnamon rolls in total.
# </REASONING>
#
# <SOLUTION>
# 16.0
# </SOLUTION>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>What's the computing and wirless total for semiconductor demand in 2014?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 197.3
# Response: addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  addCriterion
#
#  自动生成
# <REASONING>
# To find the total demand for computing and wireless in 2014, we need to add the values for these two categories together.
#
# - Computing: 105.4 billion U.S. dollars
# - Wireless: 91.9 billion U.S. dollars
#
# Adding these values:
# 105.4 + 91.9 = 197.3 billion U.S. dollars
# </REASONING>
#
# <SOLUTION>
# 197.3 </SOLUTION>
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Subtract all purple matte blocks. Subtract all brown things. How many objects are left?, provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 5
# Response: addCriterion
# Submit
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>In $\odot M$, $FL=24,HJ=48$, and $m \widehat {HP}=65$. Find $m \widehat {HJ}$., provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 130
# Response: addCriterion
#  국
# -------------------- Question:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|vision_end|>Find x. Round to the nearest tenth.
# , provide your reasoning between <REASONING> and </REASONING> and then your final answer between <SOLUTION> and (put a float here) </SOLUTION><|im_end|>
#
# Answer:
# 5.8
# Response: addCriterion
# <REASONING>
# To solve for \(x\) in the given triangle, we can use the Law of Sines. The Law of Sines states that the ratio of the length of a side to the sine of its opposite angle is the same for all three sides of the triangle. In the formula:
#
# \[
# \frac{a}{\sin B} = \frac{b}{\sin C}
# \]
#
# Here, \(b\) is the side we know, and we are trying to find the length of side \(xA\).
#
# First, let's identify the angles and the sides:
# - The angle at vertex \(A\) is \(97^\circ\).
# - The angle at vertex \(B\) is \(21^\circ\).
# - Therefore, the angle at vertex \(C\) is \(180^\circ - 97^\circ - 21^\circ = 62^\circ\).
#
# We can set up the equation using the Law of Sines:
#
# \[
# \frac{16}{\sin 62^\circ} = \frac{x}{\sin 97^\circ}
# \]
#
# Solving for \(x\):
#
# \[
# x = \frac{16 \cdot \sin 97^\circ}{\sin 62^\circ}
# \]
#
# Now, we can calculate the values of the sines and then solve for \(x\).
# </REASONING>
#
# <SOLUTION>
# To find \( x \), we use the Law of Sines:
#
# \[
# \frac{16}{\sin 62^\circ} = \frac{x}{\sin 97^\circ}
# \]
#
# Calculate \(\sin 62^\circ\) and \(\sin 97^\circ\):
#
# \[
# \sin 62^\circ \approx 0.8829
# \]
# \[
# \sin 97^\circ \approx 0.9986
# \]
#
# Then,
#
# \[
# x = \frac{16 \cdot 0.9986}{0.8829} \approx \frac{16 \cdot 0.9986}{0.8829} \approx \frac{15.9776}{0.8829} \approx 17.9993
# \]
#
# Rounding to the nearest tenth:
#
# \[
# x \approx 18.0
# \]
#
# </SOLUTION>

# %% [markdown]
# <a name="Inference"></a>
# ### Inference

# %% [markdown]
# And now with the LoRA we just trained with GRPO - we first save the LoRA first!

# %%
model.save_lora("grpo_lora")

# %% [markdown]
# We try calling vLLM with our trained RL model:

# %%
from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 1.0,
    top_k = 50,
    max_tokens = 1024,
)

outputs = model.fast_generate(
    {
        "prompt": train_dataset[100]["prompt"],
        "multi_modal_data": {"image": train_dataset[100]["image"]}
    },
    sampling_params,
    lora_request = model.load_lora("grpo_lora"))
print(outputs[0].outputs[0].text)

# %% [markdown]
# Verify LoRA is actually trained!

# %%
from safetensors import safe_open

tensors = {}
with safe_open("grpo_lora/adapter_model.safetensors", framework = "pt") as f:
    # Verify both A and B are non zero
    for key in f.keys():
        tensor = f.get_tensor(key)
        n_zeros = (tensor == 0).sum() / tensor.numel()
        assert(n_zeros.item() != tensor.numel())

# %% [markdown]
# <a name="Save"></a>
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False:
    model.save_pretrained("model")
    tokenizer.save_pretrained("model")
if False:
    model.push_to_hub("hf/model", token = "")
    tokenizer.push_to_hub("hf/model", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.
#
# [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to multiple GGUF options - much faster if you want multiple!
if False:
    model.push_to_hub_gguf(
        "hf/model", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "",
    )

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in llama.cpp.
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Special Credits to [GAD-Cell](https://github.com/GAD-cell) for helping Unsloth create this notebook and bringing VLM GRPO into Unsloth!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
